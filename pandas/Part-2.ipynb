# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd

# %%
titan=pd.read_csv("titanic.csv")

# %%
titan
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import numpy as np

# %%
titan
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titan.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titan_age_null=np.where(titan["Age"].isnull()==True)
# this is giving the rows at which the age is null

# %%
titan[titan["Age"].isnull()!=True]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titan_age_null
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154, 158, 159, 166, 168, 176, 180, 181, 185, 186,
#         196, 198, 201, 214, 223, 229, 235, 240, 241, 250, 256, 260, 264,
#         270, 274, 277, 284, 295, 298, 300, 301, 303, 304, 306, 324, 330,
#         334, 335, 347, 351, 354, 358, 359, 364, 367, 368, 375, 384, 388,
#         409, 410, 411, 413, 415, 420, 425, 428, 431, 444, 451, 454, 457,
#         459, 464, 466, 468, 470, 475, 481, 485, 490, 495, 497, 502, 507,
#         511, 517, 522, 524, 527, 531, 533, 538, 547, 552, 557, 560, 563,
#         564, 568, 573, 578, 584, 589, 593, 596, 598, 601, 602, 611, 612,
#         613, 629, 633, 639, 643, 648, 650, 653, 656, 667, 669, 674, 680,
#         692, 697, 709, 711, 718, 727, 732, 738, 739, 740, 760, 766, 768,
#         773, 776, 778, 783, 790, 792, 793, 815, 825, 826, 828, 832, 837,
# ...

# %%
# iloc
# it will only give the rows that you mention
# you can give an integer or a list of integers to remove
titan.iloc[2]
# Out:
# PassengerId                         3
# Survived                            1
# Pclass                              3
# Name           Heikkinen, Miss. Laina
# Sex                            female
# Age                              26.0
# SibSp                               0
# Parch                               0
# Ticket               STON/O2. 3101282
# Fare                            7.925
# Cabin                             NaN
# Embarked                            S
# Name: 2, dtype: object

# %%
titan.iloc[[2,3]]
# Out:
#    PassengerId  Survived  Pclass  \
# 2            3         1       3
# 3            4         1       1
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 2                        Heikkinen, Miss. Laina  female  26.0      0      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
#
#              Ticket    Fare Cabin Embarked
# 2  STON/O2. 3101282   7.925   NaN        S
# 3            113803  53.100  C123        S

# %%
titan.iloc[titan_age_null]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
titan["Fare"]==max(titan["Fare"])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Fare, Length: 891, dtype: bool

# %%
titan["Fare"]
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
max(titan["Fare"])
# Out:
# 512.3292

# %%
titan[titan["Fare"]==max(titan["Fare"])]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
temp=np.where(titan["Fare"]==max(titan["Fare"]))

# %%
temp
# Out:
# (array([258, 679, 737], dtype=int64),)

# %%
highest_paid_ones=titan.iloc[temp]

# %%
highest_paid_ones
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
highest_paid_ones.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
highest_paid_ones
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
np.where(highest_paid_ones["Cabin"]=="NaN")
# not working
# Out:
# (array([], dtype=int64),)

# %%
highest_paid_ones[highest_paid_ones["Cabin"].isnull()]
# Out:
#      PassengerId  Survived  Pclass              Name     Sex   Age  SibSp  \
# 258          259         1       1  Ward, Miss. Anna  female  35.0      0
#
#      Parch    Ticket      Fare Cabin Embarked
# 258      0  PC 17755  512.3292   NaN        C

# %%
highest_paid_ones[highest_paid_ones["Cabin"].isnull()]["Age"]
# Out:
# 258    35.0
# Name: Age, dtype: float64

# %%
titan
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
survived=titan[titan["Survived"]==True]

# %%
survived
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
survived[survived["Sex"]=="male"]
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 17            18         1       2     Williams, Mr. Charles Eugene  male
# 21            22         1       2            Beesley, Mr. Lawrence  male
# 23            24         1       1     Sloper, Mr. William Thompson  male
# 36            37         1       3                 Mamee, Mr. Hanna  male
# 55            56         1       1                Woolner, Mr. Hugh  male
# ..           ...       ...     ...                              ...   ...
# 838          839         1       3                  Chip, Mr. Chang  male
# 839          840         1       1             Marechal, Mr. Pierre  male
# 857          858         1       1           Daly, Mr. Peter Denis   male
# 869          870         1       3  Johnson, Master. Harold Theodor  male
# 889          890         1       1            Behr, Mr. Karl Howell  male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# ...

# %%
titan
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# mergin two filters all together

# %%
titan[(titan.Survived==0) & (titan.Sex=="male")]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 881          882         0       3              Markun, Mr. Johann  male
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
titan[(titan["Survived"]==1) & (titan["Sex"]=="male")]
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 17            18         1       2     Williams, Mr. Charles Eugene  male
# 21            22         1       2            Beesley, Mr. Lawrence  male
# 23            24         1       1     Sloper, Mr. William Thompson  male
# 36            37         1       3                 Mamee, Mr. Hanna  male
# 55            56         1       1                Woolner, Mr. Hugh  male
# ..           ...       ...     ...                              ...   ...
# 838          839         1       3                  Chip, Mr. Chang  male
# 839          840         1       1             Marechal, Mr. Pierre  male
# 857          858         1       1           Daly, Mr. Peter Denis   male
# 869          870         1       3  Johnson, Master. Harold Theodor  male
# 889          890         1       1            Behr, Mr. Karl Howell  male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# ...

# %%
titan["newCol"]="knk"

# %%
titan
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titan
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dict_values={"id":1,"name":"knk","gender":"male"}
# if we have the only the dictonary values,we can convert them into a pd.series
# if we have a couple of dictornary values , we can convert them into a pd.DataFrame

# %%
pd.Series(dict_values)
# Out:
# id           1
# name       knk
# gender    male
# dtype: object

# %%
pd.DataFrame(dict_values,index=["id","name","gender"])
# Out:
#         id name gender
# id       1  knk   male
# name     1  knk   male
# gender   1  knk   male

# %%
arr=np.random.rand(3)

# %%
arr
# Out:
# array([0.43120333, 0.41765023, 0.25089692])

# %%
arr1=np.random.rand(3,4)

# %%
arr1
# Out:
# array([[0.64040907, 0.37198565, 0.23982812, 0.68625369],
#        [0.34455178, 0.54181604, 0.45058625, 0.47728198],
#        [0.14505033, 0.55422928, 0.2595331 , 0.40453458]])

# %%
ser=pd.Series(np.random.rand(3),index=["ab","bb","bc"])

# %%
ser
# Out:
# ab    0.401180
# bb    0.391874
# bc    0.030480
# dtype: float64

# %%
ser.iloc[[0,1]]
# iloc will give the acording to the normal row no
# Out:
# ab    0.401180
# bb    0.391874
# dtype: float64

# %%
# loc is almost similar to the iloc,
# but loc is named index
ser.loc["ab"]
# Out:
# 0.40117964383145066

# %%
df=pd.DataFrame(np.random.randint(1,100,(4,5)),index=["a","b","c","d"],columns=["e","f","g","h","i"])

# %%
df
# Out:
#     e   f   g   h   i
# a  44  97  27  67  76
# b  72  50  55  99  94
# c   9  34  39  69   9
# d   1  42  21  42  74

# %%
df.loc[["b","c"],["f","h"]]
# Out:
#     f   h
# b  50  99
# c  34  69

# %%
df.iloc[[1,3],[1,3]]
# Out:
#     f   h
# b  50  99
# d  42  42

# %%
df.drop("a")
# by default the axis=0 means row
# Out:
#     e   f   g   h   i
# b  72  50  55  99  94
# c   9  34  39  69   9
# d   1  42  21  42  74

# %%
df.drop("e",axis=1)
# axis =0 means column
# Out:
#     f   g   h   i
# a  97  27  67  76
# b  50  55  99  94
# c  34  39  69   9
# d  42  21  42  74

# %%
# it we did not put the inplace =True ,it will remove that row only for this moment
# actually it will not drop , to drop you have to use the inplace=True
df.drop("b",inplace=True)

# %%
df
# Out:
#    e   f   g   h   i
# c  9  34  39  69   9
# d  1  42  21  42  74

# %%
# difference between the rand and randint
# rand only give the values in between 0 and 1 as fractional
# randint will give the integer values in between the digits that we mentioned
# search for those using ctrl+f

# %%
df
# Out:
#    e   f   g   h   i
# c  9  34  39  69   9
# d  1  42  21  42  74

# %%
for i in df.index:
    for j in df.columns:
        if(df.loc[i,j]>10): 
            print(i,j,df.loc[i,j])
# Out:
# c f 34
# c g 39
# c h 69
# d f 42
# d g 21
# d h 42
# d i 74

# %%
d = {'key1':[1,2,3,4,np.nan],"key2":["sudh" ,"kumar" , np.nan,5,6] ,'key3' :[np.nan,np.nan,np.nan,3,8]}
df = pd.DataFrame(d)

# %%
df
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 2   3.0    NaN   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna()
# we are removing the if any rows has null value
# Out:
#    key1 key2  key3
# 3   4.0    5   3.0

# %%
d = {'key1':[1,2,3,4,np.nan],"key2":["sudh" ,"kumar" , np.nan,5,6] ,'key3' :[np.nan,np.nan,np.nan,3,8]}
df = pd.DataFrame(d)

# %%
df
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 2   3.0    NaN   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna(axis=1)
# we are removing the if any columns has null value
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
df
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 2   3.0    NaN   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna(thresh=0)
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 2   3.0    NaN   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna(thresh=2)
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
import pandas as pd

# %%
d1 = {'name' :['sudh' , 'visal' , 'umang', 'vishal' ,'umang'],"mail_id" :["sudh@gmail.com", "vishal@gmail.com",'umang@gmail.com','vishal@gmail.com','umang@gmail.com'],
     'salary' :[100,200,500,200,500]}

# %%
d1
# Out:
# {'name': ['sudh', 'visal', 'umang', 'vishal', 'umang'],
#  'mail_id': ['sudh@gmail.com',
#   'vishal@gmail.com',
#   'umang@gmail.com',
#   'vishal@gmail.com',
#   'umang@gmail.com'],
#  'salary': [100, 200, 500, 200, 500]}

# %%
df=pd.DataFrame(d1)

# %%
df
# Out:
#      name           mail_id  salary
# 0    sudh    sudh@gmail.com     100
# 1   visal  vishal@gmail.com     200
# 2   umang   umang@gmail.com     500
# 3  vishal  vishal@gmail.com     200
# 4   umang   umang@gmail.com     500

# %%
df.groupby("mail_id").describe()
# Out:
#                  salary
#                   count   mean  std    min    25%    50%    75%    max
# mail_id
# sudh@gmail.com      1.0  100.0  NaN  100.0  100.0  100.0  100.0  100.0
# umang@gmail.com     2.0  500.0  0.0  500.0  500.0  500.0  500.0  500.0
# vishal@gmail.com    2.0  200.0  0.0  200.0  200.0  200.0  200.0  200.0

# %%
df.groupby("name").mean()
# Out:
#         salary
# name
# sudh     100.0
# umang    500.0
# visal    200.0
# vishal   200.0

# %%
df.groupby("name").sum()
# Out:
#         salary
# name
# sudh       100
# umang     1000
# visal      200
# vishal     200

# %%
import numpy as np

# %%
df=pd.DataFrame(np.random.randn(10,4),index=pd.date_range('2021-07-18',periods=10),columns=['a','b','c','d'])

# %%
df
# Out:
#                    a         b         c         d
# 2021-07-18 -0.411583 -2.032570  0.092962 -2.102466
# 2021-07-19 -0.193062 -0.247767  0.340711 -0.104438
# 2021-07-20 -0.139270  0.741434 -1.080758  0.479491
# 2021-07-21 -1.490598  0.118458  0.813333 -0.691590
# 2021-07-22  0.663673 -0.482931 -0.842960  2.116968
# 2021-07-23  0.172213 -1.180357  0.200839  0.835938
# 2021-07-24  0.722762 -1.894864 -0.225611  0.533298
# 2021-07-25  0.919130 -0.958142  0.177760  0.562164
# 2021-07-26  1.403875 -1.067145  0.380888  0.279089
# 2021-07-27 -0.315512  0.153163  0.619077  0.297616

# %%
df['new']=df['a']+df['b']

# %%
df
# Out:
#                    a         b         c         d       new
# 2021-07-18 -0.411583 -2.032570  0.092962 -2.102466 -2.444153
# 2021-07-19 -0.193062 -0.247767  0.340711 -0.104438 -0.440830
# 2021-07-20 -0.139270  0.741434 -1.080758  0.479491  0.602164
# 2021-07-21 -1.490598  0.118458  0.813333 -0.691590 -1.372141
# 2021-07-22  0.663673 -0.482931 -0.842960  2.116968  0.180742
# 2021-07-23  0.172213 -1.180357  0.200839  0.835938 -1.008144
# 2021-07-24  0.722762 -1.894864 -0.225611  0.533298 -1.172102
# 2021-07-25  0.919130 -0.958142  0.177760  0.562164 -0.039012
# 2021-07-26  1.403875 -1.067145  0.380888  0.279089  0.336730
# 2021-07-27 -0.315512  0.153163  0.619077  0.297616 -0.162349

# %%
df['new_square_d']=df['d'].apply(lambda x:x*x)

# %%
df
# Out:
#                    a         b         c         d       new  new_square_d
# 2021-07-18 -0.411583 -2.032570  0.092962 -2.102466 -2.444153      4.420362
# 2021-07-19 -0.193062 -0.247767  0.340711 -0.104438 -0.440830      0.010907
# 2021-07-20 -0.139270  0.741434 -1.080758  0.479491  0.602164      0.229912
# 2021-07-21 -1.490598  0.118458  0.813333 -0.691590 -1.372141      0.478297
# 2021-07-22  0.663673 -0.482931 -0.842960  2.116968  0.180742      4.481553
# 2021-07-23  0.172213 -1.180357  0.200839  0.835938 -1.008144      0.698792
# 2021-07-24  0.722762 -1.894864 -0.225611  0.533298 -1.172102      0.284407
# 2021-07-25  0.919130 -0.958142  0.177760  0.562164 -0.039012      0.316029
# 2021-07-26  1.403875 -1.067145  0.380888  0.279089  0.336730      0.077891
# 2021-07-27 -0.315512  0.153163  0.619077  0.297616 -0.162349      0.088575

# %%
df['new_log_d']=df['d'].apply(lambda x:np.log(x))

# %%
df
# Out:
#                    a         b         c         d       new  new_square_d  \
# 2021-07-18 -0.411583 -2.032570  0.092962 -2.102466 -2.444153      4.420362
# 2021-07-19 -0.193062 -0.247767  0.340711 -0.104438 -0.440830      0.010907
# 2021-07-20 -0.139270  0.741434 -1.080758  0.479491  0.602164      0.229912
# 2021-07-21 -1.490598  0.118458  0.813333 -0.691590 -1.372141      0.478297
# 2021-07-22  0.663673 -0.482931 -0.842960  2.116968  0.180742      4.481553
# 2021-07-23  0.172213 -1.180357  0.200839  0.835938 -1.008144      0.698792
# 2021-07-24  0.722762 -1.894864 -0.225611  0.533298 -1.172102      0.284407
# 2021-07-25  0.919130 -0.958142  0.177760  0.562164 -0.039012      0.316029
# 2021-07-26  1.403875 -1.067145  0.380888  0.279089  0.336730      0.077891
# 2021-07-27 -0.315512  0.153163  0.619077  0.297616 -0.162349      0.088575
#
#             new_log_d
# 2021-07-18        NaN
# 2021-07-19        NaN
# 2021-07-20  -0.735030
# 2021-07-21        NaN
# 2021-07-22   0.749985
# ...

# %%
def test(x):
    if(x<0):
        return x
    else:
        return np.log(x)
df['new_square_d_log_d']=df['d'].apply(test)

# %%
df
# Out:
#                    a         b         c         d       new  new_square_d  \
# 2021-07-18 -0.411583 -2.032570  0.092962 -2.102466 -2.444153      4.420362
# 2021-07-19 -0.193062 -0.247767  0.340711 -0.104438 -0.440830      0.010907
# 2021-07-20 -0.139270  0.741434 -1.080758  0.479491  0.602164      0.229912
# 2021-07-21 -1.490598  0.118458  0.813333 -0.691590 -1.372141      0.478297
# 2021-07-22  0.663673 -0.482931 -0.842960  2.116968  0.180742      4.481553
# 2021-07-23  0.172213 -1.180357  0.200839  0.835938 -1.008144      0.698792
# 2021-07-24  0.722762 -1.894864 -0.225611  0.533298 -1.172102      0.284407
# 2021-07-25  0.919130 -0.958142  0.177760  0.562164 -0.039012      0.316029
# 2021-07-26  1.403875 -1.067145  0.380888  0.279089  0.336730      0.077891
# 2021-07-27 -0.315512  0.153163  0.619077  0.297616 -0.162349      0.088575
#
#             new_log_d  new_square_d_log_d
# 2021-07-18        NaN           -2.102466
# 2021-07-19        NaN           -0.104438
# ...

# %%
df.sort_values(by='b')
# Out:
#                    a         b         c         d       new  new_square_d  \
# 2021-07-18 -0.411583 -2.032570  0.092962 -2.102466 -2.444153      4.420362
# 2021-07-24  0.722762 -1.894864 -0.225611  0.533298 -1.172102      0.284407
# 2021-07-23  0.172213 -1.180357  0.200839  0.835938 -1.008144      0.698792
# 2021-07-26  1.403875 -1.067145  0.380888  0.279089  0.336730      0.077891
# 2021-07-25  0.919130 -0.958142  0.177760  0.562164 -0.039012      0.316029
# 2021-07-22  0.663673 -0.482931 -0.842960  2.116968  0.180742      4.481553
# 2021-07-19 -0.193062 -0.247767  0.340711 -0.104438 -0.440830      0.010907
# 2021-07-21 -1.490598  0.118458  0.813333 -0.691590 -1.372141      0.478297
# 2021-07-27 -0.315512  0.153163  0.619077  0.297616 -0.162349      0.088575
# 2021-07-20 -0.139270  0.741434 -1.080758  0.479491  0.602164      0.229912
#
#             new_log_d  new_square_d_log_d
# 2021-07-18        NaN           -2.102466
# 2021-07-24  -0.628674           -0.628674
# ...

# %%
df.index
# Out:
# DatetimeIndex(['2021-07-18', '2021-07-19', '2021-07-20', '2021-07-21',
#                '2021-07-22', '2021-07-23', '2021-07-24', '2021-07-25',
#                '2021-07-26', '2021-07-27'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['a', 'b', 'c', 'd', 'new', 'new_square_d', 'new_log_d',
#        'new_square_d_log_d'],
#       dtype='object')

# %%
df['new_date']=df.index

# %%
df
# Out:
#                    a         b         c         d       new  new_square_d  \
# 2021-07-18 -0.411583 -2.032570  0.092962 -2.102466 -2.444153      4.420362
# 2021-07-19 -0.193062 -0.247767  0.340711 -0.104438 -0.440830      0.010907
# 2021-07-20 -0.139270  0.741434 -1.080758  0.479491  0.602164      0.229912
# 2021-07-21 -1.490598  0.118458  0.813333 -0.691590 -1.372141      0.478297
# 2021-07-22  0.663673 -0.482931 -0.842960  2.116968  0.180742      4.481553
# 2021-07-23  0.172213 -1.180357  0.200839  0.835938 -1.008144      0.698792
# 2021-07-24  0.722762 -1.894864 -0.225611  0.533298 -1.172102      0.284407
# 2021-07-25  0.919130 -0.958142  0.177760  0.562164 -0.039012      0.316029
# 2021-07-26  1.403875 -1.067145  0.380888  0.279089  0.336730      0.077891
# 2021-07-27 -0.315512  0.153163  0.619077  0.297616 -0.162349      0.088575
#
#             new_log_d  new_square_d_log_d   new_date
# 2021-07-18        NaN           -2.102466 2021-07-18
# ...

# %%
df.dtypes
# Out:
# a                            float64
# b                            float64
# c                            float64
# d                            float64
# new                          float64
# new_square_d                 float64
# new_log_d                    float64
# new_square_d_log_d           float64
# new_date              datetime64[ns]
# dtype: object

# %%
df['day']=df.index.day

# %%
df['month']=df.index.month

# %%
df['year']=df.index.year

# %%
df
# Out:
#                    a         b         c         d       new  new_square_d  \
# 2021-07-18 -0.411583 -2.032570  0.092962 -2.102466 -2.444153      4.420362
# 2021-07-19 -0.193062 -0.247767  0.340711 -0.104438 -0.440830      0.010907
# 2021-07-20 -0.139270  0.741434 -1.080758  0.479491  0.602164      0.229912
# 2021-07-21 -1.490598  0.118458  0.813333 -0.691590 -1.372141      0.478297
# 2021-07-22  0.663673 -0.482931 -0.842960  2.116968  0.180742      4.481553
# 2021-07-23  0.172213 -1.180357  0.200839  0.835938 -1.008144      0.698792
# 2021-07-24  0.722762 -1.894864 -0.225611  0.533298 -1.172102      0.284407
# 2021-07-25  0.919130 -0.958142  0.177760  0.562164 -0.039012      0.316029
# 2021-07-26  1.403875 -1.067145  0.380888  0.279089  0.336730      0.077891
# 2021-07-27 -0.315512  0.153163  0.619077  0.297616 -0.162349      0.088575
#
#             new_log_d  new_square_d_log_d   new_date  day  month  year
# 2021-07-18        NaN           -2.102466 2021-07-18   18      7  2021
# ...

# %%
df['day_name']=df.index.day_name()

# %%
df
# Out:
#                    a         b         c         d       new  new_square_d  \
# 2021-07-18 -0.411583 -2.032570  0.092962 -2.102466 -2.444153      4.420362
# 2021-07-19 -0.193062 -0.247767  0.340711 -0.104438 -0.440830      0.010907
# 2021-07-20 -0.139270  0.741434 -1.080758  0.479491  0.602164      0.229912
# 2021-07-21 -1.490598  0.118458  0.813333 -0.691590 -1.372141      0.478297
# 2021-07-22  0.663673 -0.482931 -0.842960  2.116968  0.180742      4.481553
# 2021-07-23  0.172213 -1.180357  0.200839  0.835938 -1.008144      0.698792
# 2021-07-24  0.722762 -1.894864 -0.225611  0.533298 -1.172102      0.284407
# 2021-07-25  0.919130 -0.958142  0.177760  0.562164 -0.039012      0.316029
# 2021-07-26  1.403875 -1.067145  0.380888  0.279089  0.336730      0.077891
# 2021-07-27 -0.315512  0.153163  0.619077  0.297616 -0.162349      0.088575
#
#             new_log_d  new_square_d_log_d   new_date  day  month  year  \
# ...
