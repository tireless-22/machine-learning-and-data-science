# %%
print("hello")
# Out:
# hello

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
np.random.seed(20)
# if we use seed the values are same at anytime on any computer
df=pd.DataFrame(np.random.rand(1000,1),index=pd.date_range('2021-07-18',periods=1000),columns=['data'])

# %%
df
# Out:
#                 data
# 2021-07-18  0.588131
# 2021-07-19  0.897714
# 2021-07-20  0.891531
# 2021-07-21  0.815837
# 2021-07-22  0.035890
# ...              ...
# 2024-04-08  0.992189
# 2024-04-09  0.756037
# 2024-04-10  0.299186
# 2024-04-11  0.261712
# 2024-04-12  0.968979
#
# [1000 rows x 1 columns]

# %%
df.plot()
# 1st one is on x-axis and second is on the y-axis
# Out:
# <AxesSubplot:>

# %%
# 57

# %%
df.data.cumsum().plot()
# cumsum means cummutlative sum
# Out:
# <AxesSubplot:>

# %%
df["data1"]=df.data.cumsum()

# %%
df["data2"]=df.data.apply(lambda x:x*x*x)

# %%
df
# Out:
#                 data       data1     data2
# 2021-07-18  0.588131    0.588131  0.203433
# 2021-07-19  0.897714    1.485845  0.723458
# 2021-07-20  0.891531    2.377375  0.708613
# 2021-07-21  0.815837    3.193213  0.543014
# 2021-07-22  0.035890    3.229102  0.000046
# ...              ...         ...       ...
# 2024-04-08  0.992189  495.812936  0.976749
# 2024-04-09  0.756037  496.568973  0.432145
# 2024-04-10  0.299186  496.868159  0.026781
# 2024-04-11  0.261712  497.129872  0.017926
# 2024-04-12  0.968979  498.098851  0.909794
#
# [1000 rows x 3 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
dff=sns.load_dataset("iris")
# seaborn contains some popular datasets

# %%
dff
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
dff.plot(figsize=(10, 10))
# figsize takes two arguments lenght and width
# Out:
# <AxesSubplot:>

# %%
graph_dff=dff.plot(title="iris dataSet")
graph_dff.set_xlabel("this is x label")
graph_dff.set_ylabel("this is y label")
# Out:
# Text(0, 0.5, 'this is y label')

# %%
dff
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
dff.iloc[0]
# Out:
# sepal_length       5.1
# sepal_width        3.5
# petal_length       1.4
# petal_width        0.2
# species         setosa
# Name: 0, dtype: object

# %%
dff.iloc[0][0:4]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: object

# %%
dff.iloc[0][0:4].plot()
# Out:
# <AxesSubplot:>

# %%
dff.iloc[0][0:4].plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
titan=sns.load_dataset("titanic")

# %%
titan
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titan['pclass'].plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
survived_data=titan["survived"].plot(kind="bar",figsize=(15,10),title="surveved bar graph")

# %%
np_data=np.random.rand(10,4)

# %%
np_data
# Out:
# array([[0.75446166, 0.59133398, 0.10869246, 0.4028534 ],
#        [0.26967582, 0.5730753 , 0.91685462, 0.18978472],
#        [0.94434909, 0.8201918 , 0.22963844, 0.69790388],
#        [0.70125072, 0.5701891 , 0.44804461, 0.33281154],
#        [0.10801831, 0.1214639 , 0.42036773, 0.33649677],
#        [0.38958793, 0.30191922, 0.31226487, 0.03620542],
#        [0.37892173, 0.01058084, 0.35704849, 0.08315787],
#        [0.70539505, 0.81619332, 0.26253141, 0.38246613],
#        [0.89709989, 0.43710888, 0.84218762, 0.85222508],
#        [0.1233555 , 0.15003882, 0.21402136, 0.00691652]])

# %%
df3=pd.DataFrame(np_data,columns=['a','b','c','d'])

# %%
df3
# Out:
#           a         b         c         d
# 0  0.754462  0.591334  0.108692  0.402853
# 1  0.269676  0.573075  0.916855  0.189785
# 2  0.944349  0.820192  0.229638  0.697904
# 3  0.701251  0.570189  0.448045  0.332812
# 4  0.108018  0.121464  0.420368  0.336497
# 5  0.389588  0.301919  0.312265  0.036205
# 6  0.378922  0.010581  0.357048  0.083158
# 7  0.705395  0.816193  0.262531  0.382466
# 8  0.897100  0.437109  0.842188  0.852225
# 9  0.123356  0.150039  0.214021  0.006917

# %%
df3.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df3.plot.barh()
# Out:
# <AxesSubplot:>

# %%
df3.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
1:20 hrs
